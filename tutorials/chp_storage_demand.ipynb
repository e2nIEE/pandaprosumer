# %% [markdown]
# <div style="display: flex; align-items: center;">
#   <img src="figures/pandaprosumer_logo.png" style="height:120px; margin-right:30px;">
#   <h1 style="margin: 0;">
#       PANDAPROSUMER EXAMPLE:<br><br>
#       INTERNAL COMBUSTION ENGINE COMBINED HEAT AND POWER (ICE CHP) WITH A HEAT STORAGE UNIT CONNECTED TO A SINGLE HEAT CONSUMER
#   </h1>
# </div>

# %% [markdown]
# <h3>Example prepared by:</h3>
#
#     Izak Oberčkal Pluško, Marko Keber*, Katja Klinar, Tine Seljak, Andrej Kitanovski
#
#     Faculty of Mechanical Engineering, University of Ljubljana, Slovenia
#
#     *Contact: marko.keber@fs.uni-lj.si

# %% [markdown]
# <h3>Description</h3>
#
# This tutorial describes how to create a single ICE CHP element in *pandaprosumer* and connect it to a heat storage element, which is connected to a single consumer. The user can choose the size of the ICE CHP unit, fuel type and altitude at which the ICE CHP unit is installed, while the time-dependent data (chosen cycle, air intake temperature, demand) is read from a an Excel file and stored in a pandas dataframe. The size of heat storage is defined by its capacity.

# %% [markdown]
# <img src="figures/ice_chp_storage_demand_1.png" style="height:100px">

# %% [markdown]
# <h3>Glossary:</h3>
#
# - Network: a configuration of connected energy generators and energy consumers
# - Element: a single energy generator or a single energy consumer
# - Container: a pandaprosumer data structure that contains data of an individual element; each element must have its container
# - Controller: the logic of an element that defines its behaviour and its limits
# - General controller: the first controller in the network that interacts with controllers of all other elements; this controller also manages external data
# - Map / mapping: a connection between two elements; contains information about the what is exchanged between the two elements

# %% [markdown]
# <h3>Network design philosophy:</h3>
#
# In pandaprosumer, a system's component is represented by a network element. Each element is assigned a *container* and its own *element controller*. A container is a structure that contains the component's configuration data (static input data), which can include information that will not change in the analysis such as size, etc. The behaviour of an element is governed by its *controller*. Connections between elements are defined by *mappings*, which couple output parameters of one controller to the input parameter of a controller of a connected element.
# The network is managed by a *general controller* called *ConstProfileController*. This controller is connected to all element controllers and manages time-dependent input data from external sources (e.g. Excel file). For each time step it distributes the time-dependent input data to relevant element controllers.

# %% [markdown]
# <h2>CREATING A NETWORK</h2>

# %% [markdown]
# If we are not in the pandaprosumer parent directory, we should add it to the path so that the program knows where to find the necessary functions.

# %%
import sys
import os

current_directory = os.getcwd()
parent_directory = os.path.dirname(current_directory)
sys.path.append(parent_directory)

# %% [markdown]
# <h2>1. Input data</h2>

# %% [markdown]
# First, let's import libraries required for data management.

# %%
import pandas as pd
from pandapower.timeseries.data_sources.frame_data import DFData

# %% [markdown]
# Next, we need to define properties of the ICE CHP element (name, size, fuel type, altitude), which are treated as static input data, i.e. characteristics that will not change during the analysis. Size is the nominal maximum electrical power in *kW*, the fuel type is chosen from the JSON file that contains the fuel map located in <span style="font-family: 'Courier New'; font-size: 16px;">library/chp_maps/fuel_maps.json </span>. In this example, we will consider that the fuel is natural gas, which in pandaprosumer is denoted as *ng*. The altitude is the altitude above sea level in *m* of the ICE CHP installation. We also assign a name to the ICE CHP instance.

# %%
size_kw = 1400
name = 'example_chp'
altitude_m = 0
fuel = 'ng'

# %% [markdown]
# Because we are using an instance of a *simple heat storage*, we need only its capacity to define its size. Units are in *kWh*.

# %%
q_capacity_kwh = 10000

# %% [markdown]
# We define the period of the analysis by setting its start and end time and date in the form "YYYY-MM-DD HH:MM:SS". The time resolution is given in seconds.

# %%
start = '2020-01-01 00:00:00'
end = '2020-01-02 00:00:00'
time_resolution_s = 900         # 15 min
frequency = '15min'

# %% [markdown]
# Now we import our time-dependent data and transform it into an appropriate DFData object. DFData is a pandaprosumer object that stores all data of an individual element. The DFData object is limited by the duration of the analysis defined above.

# %%
time_series_data = pd.read_excel('data/input_chp.xlsx')

dur = pd.date_range(start, end, freq=frequency, tz='utc')
time_series_data.index = dur
time_series_input = DFData(time_series_data)

print(time_series_data.head())

# %% [markdown]
# <h2>2. Creating elements of the network</h2>

# %% [markdown]
# In this example, the network is made up of three elements: an energy source, a storage unit, and an energy consumer. The source is represented by a single ICE CHP element, storage by a simple heat storage element, and the consumer is modelled by a single heat demand element. The arrangement of elements is described by two parameters; *level* and *order*. Since in this example the components are connected in series, they are all on *level 0*. The order starts with *0* and is defined for all components except for the *Const. profile*.

# %% [markdown]
# <img src="figures/ice_chp_storage_demand_2.png" style="height:100px">

# %% [markdown]
# We first define an empty prosumer *container* object. Each network has its own container, which is later filled with data and results.

# %%
from pandaprosumer.create import create_empty_prosumer_container

chp_prosumer = create_empty_prosumer_container()

# %% [markdown]
# Then we add the period of the analysis to the container using time data given above in Section 1 (input data).

# %%
from pandaprosumer.create import create_period

period = create_period(chp_prosumer, time_resolution_s, start, end, 'utc', 'default')

# %% [markdown]
# <h3>2.1. General element</h3>

# %% [markdown]
# In a pandaprosumer network, the first element is a general controller (*Const Profile controller*). It reads time-dependent input data (*input_params*) and sends it to other elements of the network (*output_params*). The element's data is stored in the *ConstProfileControllerData* class. The controller (*ConstProfileController*) for this element is created with the  *create_controlled_const_profile* function. At this point, we pass to the general controller element the previously created prosumer container, titles of data columns (*input_params*) in the input file (Excel file, in this case) and the coresponding names of output columns (*output_params*), the period of the analysis and the time-dependent data in the DFData object.

# %%
from pandaprosumer.create_controlled import create_controlled_const_profile

input_columns = ['q_demand_kw', 'cycle', 't_intake_k']
result_columns = ['q_demand_cp_kw', 'cycle_cp', 't_intake_cp_k']

cp_index = create_controlled_const_profile(chp_prosumer, input_columns, result_columns, time_series_input, period)

# %% [markdown]
# <h3>2.2. Internal combustion engine combined heat and power (ICE CHP) element</h3>

# %% [markdown]
# The first element in the network is an ICE CHP. We add the ICE CHP element in the prosumer container (ice_chp_prosumer) by including data that defines the ICE CHP instance (size, fuel, altitute, and name) and its position in the network (level, order) with the *create_controlled_ice_chp* function.

# %%
from pandaprosumer.create_controlled import create_controlled_ice_chp

ice_chp_index = create_controlled_ice_chp(chp_prosumer, size_kw, fuel, altitude_m, name, level=0, order=0)

# %% [markdown]
# <h3>2.3. Simple heat storage element</h3>

# %% [markdown]
# In the same way we create the second element in the network that represents heat storage and assign it the order 1 to define its position in the network.

# %%
from pandaprosumer.create_controlled import create_controlled_heat_storage

heat_storage_index = create_controlled_heat_storage(chp_prosumer, q_capacity_kwh, level=0, order=1)

# %% [markdown]
# <h3>2.4. Heat demand element</h3>

# %% [markdown]
# Finally, we create the consumer, which is defined in pandaprosumer as a *heat demand element*. In the same way as above, we add a heat demand element to the prosumer container. The *scaling* parameter allows us to easily adjust the demanded heat by simply scaling it. Again, the position of the element in the network is defined in the prosumer. Because the consumer is connected to the preceding element in series, it is on the same level. The higher order shows that the consumer comes after the storage element.

# %%
from pandaprosumer.create_controlled import create_controlled_heat_demand

heat_demand_index = create_controlled_heat_demand(chp_prosumer, scaling=1.0, level=0, order=2)

# %% [markdown]
# <h2>3. Creating connections (mappings) between controllers</h2>

# %% [markdown]
# ![controllers](figures/ice_chp_storage_demand_3.png)

# %% [markdown]
# For each controller we define how it is connected to other controllers. In pandaprosumer controllers can be connected in two different ways, i.e. by using *Generic Mapping* or *Fluid Mix Mapping*. The latter connects elements based on temperature levels and mass flow rates and therefore requires two outputs for each element. *Generic Mapping*, which enables connections between controllers through energy flow (thermal or electrical), requires a single output parameter, i.e. the output energy flow of one element is linked with the input energy flow of the connected element. In this case we use elements that can be connected only with *Generic Mapping* as the components are defined to allow mapping through thermal energy flows.

# %%
from pandaprosumer.mapping import GenericMapping

# %% [markdown]
# <h3>3.1. Connection 1: GENERAL CONTROLLER ---> ICE CHP</h3>

# %% [markdown]
# The general controller (*initiator_column*) instructs the ICE CHP controller (*responder_column*) what value in the Excel input file to use for *cycle* and *t_intake_k*.

# %%
GenericMapping(
    chp_prosumer,
    initiator_id=cp_index,
    initiator_column="cycle_cp",
    responder_id=ice_chp_index,
    responder_column="cycle",
);
GenericMapping(
    chp_prosumer,
    initiator_id=cp_index,
    initiator_column="t_intake_cp_k",
    responder_id=ice_chp_index,
    responder_column="t_intake_k",
);

# %% [markdown]
# <h3>3.2. Connection 2: ICE CHP ---> SIMPLE HEAT STORAGE</h3>

# %% [markdown]
# The ICE CHP controller (*initiator_column*) informs the heat storage controller (*responder_column*) about how much thermal power (*p_th_out_kw*) it can supply at each time step.

# %%
GenericMapping(
    chp_prosumer,
    initiator_id=ice_chp_index,
    initiator_column="p_th_out_kw",
    responder_id=heat_storage_index,
    responder_column="q_received_kw",
);

# %% [markdown]
# <h3>3.3. Connection 3: SIMPLE HEAT STORAGE ---> HEAT DEMAND (consumer)</h3>

# %% [markdown]
# Heat demand controller instructs the heat storage controller how much heat to supply.

# %%
GenericMapping(
    chp_prosumer,
    initiator_id=heat_storage_index,
    initiator_column="q_delivered_kw",
    responder_id=heat_demand_index,
    responder_column="q_received_kw",
);

# %% [markdown]
# <h3>3.4. Connection 4: GENERAL CONTROLLER ---> HEAT DEMAND (consumer)</h3>

# %% [markdown]
# The general controller (*initiator_column*) sends the heat demand controller (*responder_column*) information about the actual demand (*q_demand_kw*) at each time step. Values of *q_demand_kw* are read from the Excel input file.

# %%
GenericMapping(
    chp_prosumer,                                                  
    initiator_id=cp_index,                                               
    initiator_column="q_demand_cp_kw",
    responder_id=heat_demand_index,                                                
    responder_column="q_demand_kw",
);

# %% [markdown]
# <h2>RUNNING THE ANALYSIS</h2>

# %% [markdown]
# We can now run the analysis with the input data defined above.

# %%
from pandaprosumer.run_time_series import run_timeseries

run_timeseries(chp_prosumer, period, True);

# %% [markdown]
# <h2>PRINTING AND PLOTTING RESULTS</h2>

# %% [markdown]
# First, we plot the evolution of the demand from the Excel file and print the values in tabular form.

# %%
import matplotlib.pyplot as plt

# %%
time_series_data.plot(y='q_demand_kw');
plt.show()

# %%
print(chp_prosumer.heat_demand)

# %% [markdown]
# We then list the available results for the ICE CHP element. Results are stored in the form of time series, which can be plotted on a graph. The *.time_series* command lists all input and output dataframes.

# %%
print(chp_prosumer.time_series)

# %% [markdown]
# Here *.data_source* lists all available dataframes that we then specify with the *index* key in *.loc[]*.

# %%
print(chp_prosumer.time_series.data_source)

# %% [markdown]
# Before plotting we choose which quantity (column) we want to plot from the resulting dataframe. Index values can be an integer (e.g. *.loc[0]*) or the defined name of a specific component (*.loc[ice_chp_name]*) we want to look at.

# %%
print(chp_prosumer.time_series.data_source.loc[0].df.head())

# %% [markdown]
# Now we can plot the evolution of the heat that the ICE CHP generates based on the demand.

# %%
chp_prosumer.time_series.data_source.loc[0].df.p_th_out_kw.plot()
plt.show()

# %% [markdown]
# We can also plot time evolution of the state of charge (SOC) of the heat storage element.

# %%
chp_prosumer.time_series.data_source.loc[1].df.soc.plot()
plt.show()

# %% [markdown]
# <h2>ACKNOWLEDGEMENTS</h2>
#
# The authors would like to thank Pratikshya Mohanty and dr. Odile Capron from the Fraunhofer Institute for Energy Economics and Energy System Technology for their help in preparing this tutorial. Special thanks also to Pawel Lytaev and colleagues from the University of Kassel for their code reviews and suggestions during the development of the models. Support from the Senergy Nets project (https://senergynets.eu/), funded by the European Union under the Horizon Europe program (Grant Agreement No. 101075731), is gratefully acknowledged.
