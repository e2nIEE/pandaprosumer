# %%
import sys
import os
import pandas as pd
from pandapower.timeseries.data_sources.frame_data import DFData
from pandaprosumer.create import create_empty_prosumer_container
from pandaprosumer.create import create_period
from pandaprosumer.create_controlled import create_controlled_const_profile
from pandaprosumer.create_controlled import create_controlled_ice_chp
from pandaprosumer.create_controlled import create_controlled_heat_storage
from pandaprosumer.create_controlled import create_controlled_heat_demand
from pandaprosumer.mapping import GenericMapping
from pandaprosumer.run_time_series import run_timeseries
import matplotlib.pyplot as plt

# %%
size_kw = 1400
altitude_m = 0
fuel = 'ng'
name = 'example_chp'

# %%
start = '2020-01-01 00:00:00'
end = '2020-01-02 00:00:00'
time_resolution_s = 900         # 15 min
frequency = '15min'


# HEAT DEMAND
demand_data = pd.read_excel('data/input_chp_2consumers.xlsx')
dur = pd.date_range(start, end, freq=frequency, tz='utc')
demand_data.index = dur
demand_input = DFData(demand_data)

# %%
prosumer = create_empty_prosumer_container()
period = create_period(prosumer, time_resolution_s, start, end, 'utc', 'default')

# const profile controller
input_columns = ['q_demand1_kw', 'q_demand2_kw', 'cycle', 't_intake_k']
output_columns = ['q_demand1_cp_kw', 'q_demand2_cp_kw', 'cycle_cp', 't_intake_cp_k']
cp_index = create_controlled_const_profile(prosumer, input_columns, output_columns, demand_input, period)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       5 input_columns = ['q_demand1_kw', 'q_demand2_kw', 'cycle', 't_intake_k']
#       6 output_columns = ['q_demand1_cp_kw', 'q_demand2_cp_kw', 'cycle_cp', 't_intake_cp_k']
# ----> 7 cp_index = create_controlled_const_profile(prosumer, input_columns, output_columns, demand_input, period)
#
# File ~\miniconda\envs\synenv\Lib\site-packages\pandaprosumer\create_controlled.py:12, in create_controlled_const_profile(prosumer, input_columns, result_columns, period, data_source, level, order, temp_fluid_map_idx, mdot_fluid_map_idx)
#       9 def create_controlled_const_profile(prosumer, input_columns, result_columns, period, data_source, level=0, order=0,
#      10                                     temp_fluid_map_idx=None,
#      11                                     mdot_fluid_map_idx=None):
# ---> 12     const_controller_data = ConstProfileControllerData(
#      13         input_columns=input_columns,
#      14         result_columns=result_columns,
#      15         period_index=period,
#      16     )
#      17     const_profile = ConstProfileController(prosumer,
#      18                                            const_object=const_controller_data,
#      19                                            df_data=data_source,
#    (...)     22                                            temp_fluid_map_idx=temp_fluid_map_idx,
#      23                                            mdot_fluid_map_idx=mdot_fluid_map_idx)
#      24     return const_profile.index
#
# File ~\miniconda\envs\synenv\Lib\site-packages\pandaprosumer\element\element_toolbox.py:26, in enforce_types.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      24 @wraps(func)
#      25 def wrapper(*args, **kwargs):
# ---> 26     check_types(*args, **kwargs)
#      27     return func(*args, **kwargs)
#
# File ~\miniconda\envs\synenv\Lib\site-packages\pandaprosumer\element\element_toolbox.py:20, in enforce_types.<locals>.check_types(*args, **kwargs)
#      18 if value is None:
#      19     continue
# ---> 20 raise TypeError(
#      21     'Unexpected type for \'{}\' (expected {} but found {})'.format(name, type_hint, type(value)))
#
# TypeError: Unexpected type for 'period_index' (expected <class 'int'> but found <class 'pandapower.timeseries.data_sources.frame_data.DFData'>)
